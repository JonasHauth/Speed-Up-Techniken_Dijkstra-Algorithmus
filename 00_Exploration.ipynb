# %% [markdown]
# # Routing
#
#
# Basics Shortest Path
# - Dikstra (inkl. Implementierung)
#
# Problemstellung
# - Zu große Anzahl von Kanten für die Algorithmen > Techniken für schnellere Bearbeitung benötigt
#
# Speed-Up-Techiken
# - Bidirectional Search (inkl. Implementierung)
# - Leveling (inkl. Implementierung)
#
# Benchmark
# - Verschiedene Kombinationen
#
# Fazit und Ausblick
# - Einsatz bei PTV
# - Weitere Probleme

# %% [markdown]
# # Imports

# %%
import osmnx as ox
import networkx as nx
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
import pandas as pd
# Out:
# c:\Conda\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
adress = "Weingartener Straße 2, Stutensee, Deutschland"
graph1 = ox.graph_from_address(adress, dist=1000, dist_type='bbox', network_type='drive')
fig, ax = ox.plot_graph(graph1)

# %%
ox.geocode("Weingartener Straße 2, Stutensee, Deutschland")
# Out:
# (49.0932686, 8.51049415)

# %%
adress = "Weingartener Straße 2, Stutensee, Deutschland"
graph2 = ox.graph_from_address(adress, dist=3000, dist_type='bbox', network_type='drive')
fig, ax = ox.plot_graph(graph2)
